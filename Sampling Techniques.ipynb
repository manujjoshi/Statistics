# %% [markdown]
# # `Sampling Techniques`

# %%
import pandas as pd

# %%
data = pd.read_csv("Churn_Modelling.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## 1. `Simple random sampling`

# %% [markdown]
# ### method 1

# %%
test = data.sample(10)
test
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 2538       2539    15752838       Lucas          723     Spain    Male   38
# 2922       2923    15705113        P'an          685     Spain    Male   34
# 3454       3455    15814465       Ch'in          612    France    Male   24
# 133         134    15642004   Alekseeva          686    France    Male   25
# 4558       4559    15623730       Ch'iu          792    France    Male   34
# 2718       2719    15783444    Endrizzi          788    France  Female   39
# 4836       4837    15728078         Yeh          609    France    Male   26
# 9357       9358    15814405  Chesnokova          418    France  Female   46
# 6070       6071    15678173      Collee          629     Spain    Male   35
# 6596       6597    15654531        Tuan          477    France    Male   22
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
test["Geography"].value_counts()
# Out:
# France    7
# Spain     3
# Name: Geography, dtype: int64

# %%
test.index
# Out:
# Int64Index([2538, 2922, 3454, 133, 4558, 2718, 4836, 9357, 6070, 6596], dtype='int64')

# %% [markdown]
# ### method 2

# %%
import random

# %%
data.shape
# Out:
# (10000, 14)

# %%
sample_index = []
for i in range(10):
    sample_index.append(random.randint(0,9999))

# %%
sample_index
# Out:
# [1530, 552, 9304, 2171, 879, 4592, 5913, 5345, 1135, 6527]

# %%
data.iloc[sample_index,:]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 1530       1531    15640953      Bligh          611    France  Female   26
# 552         553    15763063      Price          685     Spain  Female   25
# 9304       9305    15783589    Toscano          616    France    Male   40
# 2171       2172    15747174        Hao          526   Germany    Male   58
# 879         880    15697497        She          518    France  Female   45
# 4592       4593    15658475       Lori          834    France    Male   36
# 5913       5914    15639530       Buda          679     Spain    Male   42
# 5345       5346    15639217   McKenzie          806    France    Male   34
# 1135       1136    15656121  Medvedeva          733   Germany    Male   31
# 6527       6528    15722692   Kazakova          464    France    Male   38
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1530       2  107508.93              2          1               1
# ...

# %% [markdown]
# ## 2. `Stratified sample`

# %%
st_sample = data.groupby("Geography").sample(5)
st_sample
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography Gender  Age  \
# 8283       8284    15754569    Pagnotto          664    France   Male   57
# 2192       2193    15761763    Jamieson          845    France   Male   33
# 9850       9851    15626012   Obidimkpa          459    France   Male   26
# 7960       7961    15772479  Napolitano          673    France   Male   37
# 9774       9775    15739692        Tsui          679    France   Male   42
# 4001       4002    15792064         Pai          545   Germany   Male   53
# 2929       2930    15729054    Korovina          744   Germany   Male   32
# 764         765    15672056     Kenenna          710   Germany   Male   43
# 3097       3098    15708228     Toscani          476   Germany   Male   30
# 7972       7973    15806929      Ch'ien          751   Germany   Male   36
# 5123       5124    15744606    Davidson          832     Spain   Male   29
# ...

# %%
st_sample["Geography"].value_counts()
# Out:
# France     5
# Germany    5
# Spain      5
# Name: Geography, dtype: int64

# %% [markdown]
# ## 3. `Cluster sampling`

# %%
country = data["Geography"].unique().tolist()
country
# Out:
# ['France', 'Spain', 'Germany']

# %%
import random
random.choice(country)
# Out:
# 'Germany'

# %%
random.sample(country,2)
# Out:
# ['Spain', 'Germany']

# %%
data.loc[data["Geography"].isin(['Spain', 'France'])] # using isin
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## 4. `Systematic sampling`

# %%
data.shape
# Out:
# (10000, 14)

# %%
import random
start_index = random.randint(0,9999)
start_index
# Out:
# 3448

# %%
data.iloc[3448::5,:]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3448       3449    15610903  Chukwueloka          560     Spain  Female   31
# 3453       3454    15737521         Ball          619   Germany    Male   40
# 3458       3459    15748673       Nepean          770    France  Female   37
# 3463       3464    15791216         Mann          600   Germany    Male   43
# 3468       3469    15769586        Horan          820    France  Female   49
# ...         ...         ...          ...          ...       ...     ...  ...
# 9978       9979    15703563        P'eng          774    France    Male   40
# 9983       9984    15656710        Cocci          613    France    Male   40
# 9988       9989    15589329      Pirozzi          775    France    Male   30
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
#
# ...

# %% [markdown]
# ## 5. `Multistage Stratified sampling`

# %%
st_sample = data.groupby("Geography").sample(500)
st_sample
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 2664       2665    15769582       Kang          586    France    Male   29
# 2283       2284    15624633      Kibby          702    France    Male   45
# 5059       5060    15579915    Glennon          707    France    Male   29
# 5345       5346    15639217   McKenzie          806    France    Male   34
# 1891       1892    15574783    Perkins          584    France  Female   37
# ...         ...         ...        ...          ...       ...     ...  ...
# 8141       8142    15571843   Lawrence          486     Spain    Male   24
# 3521       3522    15812706     Mazure          627     Spain    Male   49
# 2205       2206    15812982    Francis          509     Spain    Male   38
# 3583       3584    15773221     Harris          577     Spain    Male   43
# 6446       6447    15596011  Artyomova          529     Spain    Male   34
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
mul_st = st_sample.groupby(["Geography","Gender"]).sample(100)
mul_st
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9057       9058    15764153         Rowe          704    France  Female   33
# 602         603    15782569        Stout          687    France  Female   72
# 7114       7115    15575243    Gorbunova          764    France  Female   39
# 3190       3191    15625395     Chinomso          585    France  Female   28
# 9609       9610    15674833         Shao          741    France  Female   35
# ...         ...         ...          ...          ...       ...     ...  ...
# 2872       2873    15671591  Castiglione          439     Spain    Male   52
# 8656       8657    15791342     Johnston          660     Spain    Male   31
# 1154       1155    15766887      Iadanza          538     Spain    Male   39
# 3521       3522    15812706       Mazure          627     Spain    Male   49
# 4699       4700    15748597      Chester          844     Spain    Male   56
#
# ...

# %%
mul_st['Geography'].value_counts()
# Out:
# France     200
# Germany    200
# Spain      200
# Name: Geography, dtype: int64

# %%
mul_st['Gender'].value_counts()
# Out:
# Female    300
# Male      300
# Name: Gender, dtype: int64

# %% [markdown]
# # `END`
